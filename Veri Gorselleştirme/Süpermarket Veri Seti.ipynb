# %% [markdown]
# ## Süpermarket Veri Seti

# %% [markdown]
# ### Kütüphaneleri Yükle

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Veri Setini Yükle

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3073-49B7
#
#  Directory of C:\Users\murat\Documents\ECO_Nov\data_visual
#
# 11.12.2024  20:10    <DIR>          .
# 09.12.2024  19:56    <DIR>          ..
# 09.12.2024  21:55    <DIR>          .ipynb_checkpoints
# 09.12.2024  19:55           677.819 Billionaires.csv
# 09.12.2024  19:55           732.191 combine.csv
# 09.12.2024  19:55            55.966 corona_dat.csv
# 09.12.2024  19:55         1.544.122 covid19.mp4
# 09.12.2024  21:30         1.019.553 seaborn k�t�phanesi haz�r veri setleri (Tips).ipynb
# 09.12.2024  19:55           131.528 supermarket.csv
# 11.12.2024  20:10           233.022 S�permarket Veri Seti.ipynb
#                7 File(s)      4.394.201 bytes
#                3 Dir(s)   8.202.129.408 bytes free

# %%
df=pd.read_csv(r'supermarket.csv')

# %% [markdown]
# ### Keşifsel Veri Analizi - Veri Görselleştirme

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.sample(100)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 167  687-47-8271      A     Yangon        Normal    Male
# 127  189-08-9157      C  Naypyitaw        Normal  Female
# 63   199-75-8169      A     Yangon        Member    Male
# 449  449-27-2918      B   Mandalay        Member  Female
# 691  266-20-6657      C  Naypyitaw        Member    Male
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 161  275-28-0149      A     Yangon        Normal    Male
# 30   871-79-8483      B   Mandalay        Normal    Male
# 305  411-77-0180      A     Yangon        Member    Male
# 471  340-21-9136      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 167     Fashion accessories       98.98        10  49.4900  1039.2900
# 127     Fashion accessories       31.73         9  14.2785   299.8485
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['Branch'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
#Maksimum Toplam Tutar
df[df['Total']==df['Total'].max()]
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 350        99.3        10   49.65  1042.65  2/15/2019  14:53  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# 350  993.0                 4.761905         49.65     6.6

# %%
#Ortalama Harcama
df['Total'].mean()
# Out:
# 322.966749

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %%
df['Date']
# Out:
# 0       1/5/2019
# 1       3/8/2019
# 2       3/3/2019
# 3      1/27/2019
# 4       2/8/2019
#          ...
# 995    1/29/2019
# 996     3/2/2019
# 997     2/9/2019
# 998    2/22/2019
# 999    2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
#Tarih verisini tarih formatına çevir
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
df['day']=df.Date.dt.day_name()
df['month']=df.Date.dt.month_name()

# %%
#df.set_index('Date',inplace=True)
#df

# %%
df.sort_index(ascending=False)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 999  849-09-3807      A     Yangon        Member  Female
# 998  347-56-2442      A     Yangon        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# ..           ...    ...        ...           ...     ...
# 4    373-73-7910      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 2    631-41-3108      A     Yangon        Normal    Male
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 0    750-67-8428      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 999     Fashion accessories       88.34         7  30.9190   649.2990
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# ...

# %%
df['Time'].dtype
# Out:
# dtype('O')

# %%
df['Time']=pd.to_datetime(df['Time'],format='%H:%M')

# %%
df['Time']
# Out:
# 0     1900-01-01 13:08:00
# 1     1900-01-01 10:29:00
# 2     1900-01-01 13:23:00
# 3     1900-01-01 20:33:00
# 4     1900-01-01 10:37:00
#               ...
# 995   1900-01-01 13:46:00
# 996   1900-01-01 17:16:00
# 997   1900-01-01 13:22:00
# 998   1900-01-01 15:33:00
# 999   1900-01-01 13:28:00
# Name: Time, Length: 1000, dtype: datetime64[ns]

# %%
df['Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['hour']=df['Time'].dt.hour

# %%
df['hour']
# Out:
# 0      13
# 1      10
# 2      13
# 3      20
# 4      10
#        ..
# 995    13
# 996    17
# 997    13
# 998    15
# 999    13
# Name: hour, Length: 1000, dtype: int32

# %%
df_clean=df.drop(['Date','Time'],axis=1)
df_clean
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df_clean['month'],
             palette='Set1',)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\murat\AppData\Local\Temp\ipykernel_23172\3456693951.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['month'],

# %%
df_clean.groupby('month')['Total'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
monthly_total=df_clean.groupby('month')['Total'].sum().reset_index()
monthly_total
# Out:
#       month       Total
# 0  February   97219.374
# 1   January  116291.868
# 2     March  109455.507

# %%
sns.barplot(x=monthly_total['month'],y=monthly_total['Total'])
# Out:
# <Axes: xlabel='month', ylabel='Total'>

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.barplot(x='month',
            y='Total',
           data=df_clean.groupby('month')['Total'].sum().reset_index(),
           palette='Set1')
# Out:
# <Axes: xlabel='month', ylabel='Total'>

# %%
sns.countplot(x='month',
             hue='Branch',
             data=df_clean)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
monthly_branch_total=df_clean.groupby(['month','Branch'])['Total'].sum().reset_index()
monthly_branch_total
# Out:
#       month Branch       Total
# 0  February      A  29860.1205
# 1  February      B  34424.2710
# 2  February      C  32934.9825
# 3   January      A  38681.1285
# 4   January      B  37176.0585
# 5   January      C  40434.6810
# 6     March      A  37659.1215
# 7     March      B  34597.3425
# 8     March      C  37199.0430

# %%
sns.barplot(x='month',
           y='Total',
           hue='Branch',
           data=monthly_branch_total)
# Out:
# <Axes: xlabel='month', ylabel='Total'>

# %%
sns.lineplot(x='month',
           y='Total',
           hue='Branch',
           data=monthly_branch_total)
# Out:
# <Axes: xlabel='month', ylabel='Total'>

# %%
#Cinsiyete göre yapılan alış veriş
sns.countplot(x=df['Branch'],
             hue=df['Gender'])
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
gender_branch_total=df_clean.groupby(['Gender','Branch'])['Total'].sum().reset_index()
gender_branch_total
# Out:
#    Gender Branch       Total
# 0  Female      A  53269.1670
# 1  Female      B  52928.2950
# 2  Female      C  61685.4630
# 3    Male      A  52931.2035
# 4    Male      B  53269.3770
# 5    Male      C  48883.2435

# %%
sns.barplot(x='Gender',
           y='Total',
           hue='Branch',
           data=gender_branch_total)
# Out:
# <Axes: xlabel='Gender', ylabel='Total'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Product line'],
             hue=df['Gender'],
              order=df['Product line'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
gen_br_prod_total=df_clean.groupby(['Product line','Gender','Branch'])['Total'].sum().reset_index().sort_values('Total',ascending=False)
gen_br_prod_total
# Out:
#               Product line  Gender Branch       Total
# 14      Food and beverages  Female      C  15661.1595
# 22       Health and beauty    Male      B  13580.3115
# 24      Home and lifestyle  Female      A  12636.8130
# 8      Fashion accessories  Female      C  11519.6865
# 33       Sports and travel    Male      A  11257.5225
# 32       Sports and travel  Female      C  11246.7285
# 34       Sports and travel    Male      B  10775.3835
# 13      Food and beverages  Female      B  10509.9960
# 23       Health and beauty    Male      C  10169.5860
# 15      Food and beverages    Male      A  10163.3385
# 11     Fashion accessories    Male      C  10040.3835
# 5   Electronic accessories    Male      C   9999.7590
# 0   Electronic accessories  Female      A   9966.2955
# 6      Fashion accessories  Female      A   9836.2215
# 27      Home and lifestyle    Male      A   9780.3825
# 25      Home and lifestyle  Female      B   9557.1315
# ...

# %%
gen_br_prod_total.plot(kind='barh')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['day'],
             order=df['day'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
day_total=df_clean.groupby(['day'])['Total'].sum().reset_index().sort_values('Total',ascending=False)
day_total
# Out:
#          day       Total
# 2   Saturday  56120.8095
# 5    Tuesday  51482.2455
# 4   Thursday  45349.2480
# 3     Sunday  44457.8925
# 0     Friday  43926.3405
# 6  Wednesday  43731.1350
# 1     Monday  37899.0780

# %%
sns.barplot(x='day',
           y='Total',
           data=day_total)
# Out:
# <Axes: xlabel='day', ylabel='Total'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['hour'],
             order=df['hour'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
hour_total=df_clean.groupby(['hour'])['Total'].sum().reset_index().sort_values('Total',ascending=False)
hour_total
# Out:
#     hour       Total
# 9     19  39699.5130
# 3     13  34723.2270
# 0     10  31421.4810
# 5     15  31179.5085
# 4     14  30828.3990
# 1     11  30377.3295
# 2     12  26065.8825
# 8     18  26030.3400
# 6     16  25226.3235
# 7     17  24445.2180
# 10    20  22969.5270

# %%
sns.barplot(x='hour',
           y='Total',
           data=hour_total)
# Out:
# <Axes: xlabel='hour', ylabel='Total'>

# %%
day_hour_count=df_clean.groupby(['day','hour'])['Total'].sum().reset_index().sort_values(by='Total',ascending=False)
day_hour_count
# Out:
#          day  hour      Total
# 64   Tuesday    19  9198.6720
# 31  Saturday    19  9117.3810
# 60   Tuesday    15  7020.2055
# 44  Thursday    10  6885.2280
# 3     Friday    13  6824.3070
# ..       ...   ...        ...
# 21    Monday    20  2382.6285
# 39    Sunday    16  2241.2250
# 2     Friday    12  2159.2410
# 15    Monday    14  2004.3450
# 7     Friday    17  1893.4125
#
# [77 rows x 3 columns]

# %%
c_hour_total=df_clean[df_clean['Branch']=='C'].groupby(['hour'])['Total'].sum().reset_index().sort_values('Total',ascending=False).reset_index(drop=True)
hour2=c_hour_total

# %%
sns.barplot(x='hour',
           y='Total',
           data=hour2)
# Out:
# <Axes: xlabel='hour', ylabel='Total'>

# %%
#rating ortalamaları
rat_df=df_clean.groupby('Branch')['Rating'].mean().reset_index()
rat_df
# Out:
#   Branch    Rating
# 0      A  7.027059
# 1      B  6.818072
# 2      C  7.072866

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Branch',
            y='Rating',
            data=rat_df, 
           palette='Set1')
plt.title('Şubelerin Rating Ortalamaları')
plt.xlabel('Şubeler')
plt.ylabel('Rating Ortalamaları')
plt.show()

# %%
#branşa göre satış oranları
df_clean['Branch'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.relplot(x='hour',
           y='Total',
           col='month',
           row='Branch',
           kind='line',
           hue='Gender',
           data=df_clean);

# %%
df_clean[(df_clean['Branch']=='A')  & (df_clean['month']=='January')].groupby(['hour'])['Total'].sum().reset_index().sort_values(by='Total',ascending=False)
# Out:
#     hour      Total
# 1     11  5136.2115
# 4     14  4809.1890
# 0     10  4666.7985
# 3     13  4576.1415
# 7     17  4259.0940
# 5     15  3426.7800
# 8     18  2853.0810
# 6     16  2540.6430
# 10    20  2431.9575
# 2     12  2234.2845
# 9     19  1746.9480

# %%
df_clean[(df_clean['Branch']=='B')  & (df_clean['month']=='January')].groupby(['hour'])['Total'].sum().reset_index().sort_values(by='Total',ascending=False)
# Out:
#     hour      Total
# 9     19  5973.4290
# 5     15  4786.0365
# 3     13  4432.2495
# 1     11  4320.5190
# 10    20  3717.1365
# 8     18  3163.7130
# 0     10  2767.2540
# 2     12  2477.9055
# 4     14  2333.1210
# 7     17  2103.1920
# 6     16  1101.5025

# %%
df_clean.groupby(['Branch'])['Total'].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
df_arge=df_clean[(df_clean['Branch']=='A')  & (df_clean['month']=='January')]
df_arge
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 8    665-32-9167      A  Yangon        Member  Female       Health and beauty
# 17   765-26-6951      A  Yangon        Normal    Male       Sports and travel
# 18   329-62-1586      A  Yangon        Normal    Male      Food and beverages
# ..           ...    ...     ...           ...     ...                     ...
# 942  809-69-9497      A  Yangon        Normal  Female      Home and lifestyle
# 945  489-82-1237      A  Yangon        Normal  Female  Electronic accessories
# 955  846-10-0341      A  Yangon        Normal  Female     Fashion accessories
# 967  195-06-0432      A  Yangon        Member    Male      Home and lifestyle
# 981  809-46-1866      A  Yangon        Normal    Male       Health and beauty
#
# ...

# %%
sns.barplot(x='hour',
            y='Total',
           data=df_arge)
# Out:
# <Axes: xlabel='hour', ylabel='Total'>
